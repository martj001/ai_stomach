# %%
from matplotlib import pyplot as plt
from algorithm.patient import Patient
# Out:
# /home/martin/anaconda3/lib/python3.8/site-packages/skan/csr.py:21: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @numba.jitclass(csr_spec)

# %%
pid = 9653094
patient = Patient(pid)
patient.load_data()

lesion_id = 0
# Out:
# /home/martin/JupyterLab/ai_stomach_temp/algorithm/lesion.py:149: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   mask = remove_small_objects(mask_labelled, min_size=5)
# /home/martin/JupyterLab/ai_stomach_temp/algorithm/lesion.py:165: UserWarning: Any labeled images will be returned as a boolean array. Did you mean to use a boolean array?
#   mask = remove_small_holes(self.roi_lesion_mask)

# %%
ct_obj = patient.ct_1
ct_obj.lesion_list[lesion_id].display_global()

ct_obj = patient.ct_2
ct_obj.lesion_list[lesion_id].display_global()

# %%
ct_obj = patient.ct_1
ct_obj.lesion_list[lesion_id].calculate_lesion_long(enable_skeleton_path=True)
ct_obj.lesion_list[lesion_id].display_roi_skeleton('')

ct_obj = patient.ct_2
ct_obj.lesion_list[lesion_id].calculate_lesion_long(enable_skeleton_path=True)
ct_obj.lesion_list[lesion_id].display_roi_skeleton('')

# %%
dict_features = ct_obj.extract_features('radiomics')
dict(list(dict_features.items())[0:15])
# Out:
# Shape features are only available 3D input (for 2D input, use shape2D). Found 2D input
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Shape features are only available 3D input (for 2D input, use shape2D). Found 2D input
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# {'l1_shape2D_Elongation': 0.6028647683833751,
#  'l1_shape2D_MajorAxisLength': 116.75816987619986,
#  'l1_shape2D_MaximumDiameter': array(113.63538181),
#  'l1_shape2D_MeshSurface': array(3121.5),
#  'l1_shape2D_MinorAxisLength': 70.38938703928198,
#  'l1_shape2D_Perimeter': array(418.73506474),
#  'l1_shape2D_PerimeterSurfaceRatio': array(0.13414546),
#  'l1_shape2D_PixelSurface': 3122.0,
#  'l1_shape2D_Sphericity': 0.47298489499750207,
#  'l1_firstorder_10Percentile': array(0.),
#  'l1_firstorder_90Percentile': array(59.),
#  'l1_firstorder_Energy': array(4556697.),
#  'l1_firstorder_Entropy': array(2.02594218),
# ...

# %%
ct_obj.extract_features('long')
# Out:
# {'l1_lesion_long': 140.3620548435736, 'l2_lesion_long': 132.1560097784886}
